# %% [markdown]
# # Assignment # 4
# **Name:** Shaimar R. González Morales
#
# **Date:** 3/1/ 2021

# %% [markdown]
# ## Step 1: Open txt file & read lines to a list

# %%
with open("census_cost.txt", "rt") as f:
    line_list=f.readlines() # open file

# %%
type(line_list) # list of lines
# Out:
# list

# %%
print(line_list)
# Out:
# ['Source: https://www.genealogybranches.com/censuscosts.html\n', 'Census Year\tTotal Population\tCensus Cost\tAverage Cost Per Person\n', '1790\t3,929,214\t$44,377\t1.13 cents\n', '1800\t5,308,483\t$66,109\t1.24 cents\n', '1810\t7,239,881\t$178,445\t2.46 cents\n', '1820\t9,633,822\t$208,526\t2.16 cents\n', '1830\t12,866,020\t$378,545\t2.94 cents\n', '1840\t17,069,458\t$833,371\t4.88 cents\n', '1850\t23,191,876\t$1,423,351\t6.14 cents\n', '1860\t31,443,321\t$1,969,377\t6.26 cents\n', '1870\t38,558,371\t$3,421,198\t8.87 cents\n', '1880\t50,155,783\t$5,790,678\t11.54 cents\n', '1890\t62,979,766\t$11,547,127\t18.33 cents\n', '1900\t76,303,387\t$11,854,000\t15.54 cents\n', '1910\t91,972,266\t$15,968,000\t17.07 cents\n', '1920\t105,710,620\t$25,117,000\t23.76 cents\n', '1930\t122,775,046\t$40,156,000\t32.71 cents\n', '1940\t131,669,275\t$67,527,000\t51.29 cents\n', '1950\t151,325,798\t$91,462,000\t60.44 cents\n', '1960\t179,323,175\t$127,934,000\t71.34 cents\n', '1970\t203,302,031\t$247,65
# ...

# %% [markdown]
# ## Step 2: Extract the first two lines and put them in a different list

# %%
for row in line_list: # show the txt document
    print(row)
# Out:
# Source: https://www.genealogybranches.com/censuscosts.html
#
# Census Year	Total Population	Census Cost	Average Cost Per Person
#
# 1790	3,929,214	$44,377	1.13 cents
#
# 1800	5,308,483	$66,109	1.24 cents
#
# 1810	7,239,881	$178,445	2.46 cents
#
# 1820	9,633,822	$208,526	2.16 cents
#
# 1830	12,866,020	$378,545	2.94 cents
#
# 1840	17,069,458	$833,371	4.88 cents
#
# 1850	23,191,876	$1,423,351	6.14 cents
#
# 1860	31,443,321	$1,969,377	6.26 cents
#
# 1870	38,558,371	$3,421,198	8.87 cents
#
# 1880	50,155,783	$5,790,678	11.54 cents
#
# 1890	62,979,766	$11,547,127	18.33 cents
#
# 1900	76,303,387	$11,854,000	15.54 cents
#
# 1910	91,972,266	$15,968,000	17.07 cents
#
# 1920	105,710,620	$25,117,000	23.76 cents
#
# 1930	122,775,046	$40,156,000	32.71 cents
#
# 1940	131,669,275	$67,527,000	51.29 cents
#
# 1950	151,325,798	$91,462,000	60.44 cents
#
# 1960	179,323,175	$127,934,000	71.34 cents
#
# 1970	203,302,031	$247,653,000	$1.22
#
# 1980	226,542,199	$1,078,488,000	$4.76
#
# ...

# %%
len(line_list)
# Out:
# 25

# %%
top2_list=line_list[:2] # taking the tops two elements

# %%
print(top2_list) # showing top elements in the list
# Out:
# ['Source: https://www.genealogybranches.com/censuscosts.html\n', 'Census Year\tTotal Population\tCensus Cost\tAverage Cost Per Person\n']

# %% [markdown]
# ## Step3: Put the rest of element in new list

# %%
data_list=line_list[2:25] # adding the remaining elements to a new list

# %%
print(data_list)
#showing just the data points in the list
# Out:
# ['1790\t3,929,214\t$44,377\t1.13 cents\n', '1800\t5,308,483\t$66,109\t1.24 cents\n', '1810\t7,239,881\t$178,445\t2.46 cents\n', '1820\t9,633,822\t$208,526\t2.16 cents\n', '1830\t12,866,020\t$378,545\t2.94 cents\n', '1840\t17,069,458\t$833,371\t4.88 cents\n', '1850\t23,191,876\t$1,423,351\t6.14 cents\n', '1860\t31,443,321\t$1,969,377\t6.26 cents\n', '1870\t38,558,371\t$3,421,198\t8.87 cents\n', '1880\t50,155,783\t$5,790,678\t11.54 cents\n', '1890\t62,979,766\t$11,547,127\t18.33 cents\n', '1900\t76,303,387\t$11,854,000\t15.54 cents\n', '1910\t91,972,266\t$15,968,000\t17.07 cents\n', '1920\t105,710,620\t$25,117,000\t23.76 cents\n', '1930\t122,775,046\t$40,156,000\t32.71 cents\n', '1940\t131,669,275\t$67,527,000\t51.29 cents\n', '1950\t151,325,798\t$91,462,000\t60.44 cents\n', '1960\t179,323,175\t$127,934,000\t71.34 cents\n', '1970\t203,302,031\t$247,653,000\t$1.22\n', '1980\t226,542,199\t$1,078,488,000\t$4.76\n', '1990\t248,718,301\t$2,492,830,000\t$10.02\n', '2000\t281,421,906\t$4.5 Bi
# ...

# %% [markdown]
# ## Step 4: Extract the column "Census Year" from data_list and assign them to a list named year_list

# %%
year_list= [i.split('\t', 1)[0] for i in data_list] # taking the years out of the data_list
print(year_list)
# Out:
# ['1790', '1800', '1810', '1820', '1830', '1840', '1850', '1860', '1870', '1880', '1890', '1900', '1910', '1920', '1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000', '2010*']

# %%
for n,i in enumerate(year_list):
    if i == '2010*':
        year_list[n] = '2010' # taking out '*'

# %%
year_list
# Out:
# ['1790',
#  '1800',
#  '1810',
#  '1820',
#  '1830',
#  '1840',
#  '1850',
#  '1860',
#  '1870',
#  '1880',
#  '1890',
#  '1900',
#  '1910',
#  '1920',
#  '1930',
#  '1940',
#  '1950',
#  '1960',
#  '1970',
#  '1980',
#  '1990',
#  '2000',
#  '2010']

# %%
year_list = [int(i) for i in year_list] # convert to int

# %%
year_list
# Out:
# [1790,
#  1800,
#  1810,
#  1820,
#  1830,
#  1840,
#  1850,
#  1860,
#  1870,
#  1880,
#  1890,
#  1900,
#  1910,
#  1920,
#  1930,
#  1940,
#  1950,
#  1960,
#  1970,
#  1980,
#  1990,
#  2000,
#  2010]

# %% [markdown]
# ## Step 5: Extract the "Total Population" column from the data_list and assign them to a list named "pop_list"

# %%
pop_list= [i.split('\t', 2)[1] for i in data_list] #taking the population info from list
print(pop_list)
# Out:
# ['3,929,214', '5,308,483', '7,239,881', '9,633,822', '12,866,020', '17,069,458', '23,191,876', '31,443,321', '38,558,371', '50,155,783', '62,979,766', '76,303,387', '91,972,266', '105,710,620', '122,775,046', '131,669,275', '151,325,798', '179,323,175', '203,302,031', '226,542,199', '248,718,301', '281,421,906', '308,745,538']

# %%
pop = []

for s in pop_list:

    new = s.replace(",", "") # taking commas out

    pop.append(new)

# %%
print(pop)
# Out:
# ['3929214', '5308483', '7239881', '9633822', '12866020', '17069458', '23191876', '31443321', '38558371', '50155783', '62979766', '76303387', '91972266', '105710620', '122775046', '131669275', '151325798', '179323175', '203302031', '226542199', '248718301', '281421906', '308745538']

# %%
pop_list = [int(i) for i in pop] # covert to int

# %%
print(pop_list)
# Out:
# [3929214, 5308483, 7239881, 9633822, 12866020, 17069458, 23191876, 31443321, 38558371, 50155783, 62979766, 76303387, 91972266, 105710620, 122775046, 131669275, 151325798, 179323175, 203302031, 226542199, 248718301, 281421906, 308745538]

# %% [markdown]
# ## Step 6: Extract the "Census Cost" column from the data_list and assign them to a list named "cost_list"

# %%
cost_list= [i.split('\t', 3)[2] for i in data_list] # taking cost values from data_list
print(cost_list)
# Out:
# ['$44,377', '$66,109', '$178,445', '$208,526', '$378,545', '$833,371', '$1,423,351', '$1,969,377', '$3,421,198', '$5,790,678', '$11,547,127', '$11,854,000', '$15,968,000', '$25,117,000', '$40,156,000', '$67,527,000', '$91,462,000', '$127,934,000', '$247,653,000', '$1,078,488,000', '$2,492,830,000', '$4.5 Billion', '$13 Billion']

# %%
cost = []
for c in cost_list:
    new_cost = c.replace("$", "") #taking money sign out
    cost.append(new_cost)

# %%
cost
# Out:
# ['44,377',
#  '66,109',
#  '178,445',
#  '208,526',
#  '378,545',
#  '833,371',
#  '1,423,351',
#  '1,969,377',
#  '3,421,198',
#  '5,790,678',
#  '11,547,127',
#  '11,854,000',
#  '15,968,000',
#  '25,117,000',
#  '40,156,000',
#  '67,527,000',
#  '91,462,000',
#  '127,934,000',
#  '247,653,000',
#  '1,078,488,000',
#  '2,492,830,000',
#  '4.5 Billion',
#  '13 Billion']

# %%
cost_withoutcommas = []
for e in cost:
    new_cost2 = e.replace(",", "")# taking commas out
    cost_withoutcommas.append(new_cost2)

# %%
print(cost_withoutcommas)
# Out:
# ['44377', '66109', '178445', '208526', '378545', '833371', '1423351', '1969377', '3421198', '5790678', '11547127', '11854000', '15968000', '25117000', '40156000', '67527000', '91462000', '127934000', '247653000', '1078488000', '2492830000', '4.5 Billion', '13 Billion']

# %%
 cst= []
for e in cost_withoutcommas:
    new_cost3 = e.replace("4.5 Billion", "4500000000") # covert the billions to numbers
    cst.append(new_cost3)

# %%
cst
# Out:
# ['44377',
#  '66109',
#  '178445',
#  '208526',
#  '378545',
#  '833371',
#  '1423351',
#  '1969377',
#  '3421198',
#  '5790678',
#  '11547127',
#  '11854000',
#  '15968000',
#  '25117000',
#  '40156000',
#  '67527000',
#  '91462000',
#  '127934000',
#  '247653000',
#  '1078488000',
#  '2492830000',
#  '4500000000',
#  '13 Billion']

# %%
 cst2= []
for e in cst:
    new_cost4 = e.replace("13 Billion", "13000000000") # covert the billions to numbers
    cst2.append(new_cost4)

# %%
cst2
# Out:
# ['44377',
#  '66109',
#  '178445',
#  '208526',
#  '378545',
#  '833371',
#  '1423351',
#  '1969377',
#  '3421198',
#  '5790678',
#  '11547127',
#  '11854000',
#  '15968000',
#  '25117000',
#  '40156000',
#  '67527000',
#  '91462000',
#  '127934000',
#  '247653000',
#  '1078488000',
#  '2492830000',
#  '4500000000',
#  '13000000000']

# %%
cost_list = [int(i) for i in cst2] # convert to int

# %%
cost_list
# Out:
# [44377,
#  66109,
#  178445,
#  208526,
#  378545,
#  833371,
#  1423351,
#  1969377,
#  3421198,
#  5790678,
#  11547127,
#  11854000,
#  15968000,
#  25117000,
#  40156000,
#  67527000,
#  91462000,
#  127934000,
#  247653000,
#  1078488000,
#  2492830000,
#  4500000000,
#  13000000000]

# %% [markdown]
# ## Step 7: Extract the "Average Cost per Person" column from the data_list and assign them to a list named "avg_list"

# %%
avg_list= [i.split('\t', 4)[3] for i in data_list] #taking the avg_list from data_list
print(avg_list)
# Out:
# ['1.13 cents\n', '1.24 cents\n', '2.46 cents\n', '2.16 cents\n', '2.94 cents\n', '4.88 cents\n', '6.14 cents\n', '6.26 cents\n', '8.87 cents\n', '11.54 cents\n', '18.33 cents\n', '15.54 cents\n', '17.07 cents\n', '23.76 cents\n', '32.71 cents\n', '51.29 cents\n', '60.44 cents\n', '71.34 cents\n', '$1.22\n', '$4.76\n', '$10.02\n', '$15.99\n', '$42.11\n']

# %%
avg1 = []
for c in avg_list:
    new_avg = c.replace("cents\n","") # taking cents out
    avg1.append(new_avg)

# %%
avg1
# Out:
# ['1.13 ',
#  '1.24 ',
#  '2.46 ',
#  '2.16 ',
#  '2.94 ',
#  '4.88 ',
#  '6.14 ',
#  '6.26 ',
#  '8.87 ',
#  '11.54 ',
#  '18.33 ',
#  '15.54 ',
#  '17.07 ',
#  '23.76 ',
#  '32.71 ',
#  '51.29 ',
#  '60.44 ',
#  '71.34 ',
#  '$1.22\n',
#  '$4.76\n',
#  '$10.02\n',
#  '$15.99\n',
#  '$42.11\n']

# %%
index2=avg1.index('71.34 ') #determine the index to do the division to convert to dollars

# %%
index2
# Out:
# 17

# %%
new=[]
for i in avg1:
    change = i.replace(' ','') # taking out the extra space
    new.append(change)

# %%
new
# Out:
# ['1.13',
#  '1.24',
#  '2.46',
#  '2.16',
#  '2.94',
#  '4.88',
#  '6.14',
#  '6.26',
#  '8.87',
#  '11.54',
#  '18.33',
#  '15.54',
#  '17.07',
#  '23.76',
#  '32.71',
#  '51.29',
#  '60.44',
#  '71.34',
#  '$1.22\n',
#  '$4.76\n',
#  '$10.02\n',
#  '$15.99\n',
#  '$42.11\n']

# %%
avg2 = []
for c in new:
    new_avg2 = c.replace("\n","") # taking out the \n
    avg2.append(new_avg2)

# %%
avg2
# Out:
# ['1.13',
#  '1.24',
#  '2.46',
#  '2.16',
#  '2.94',
#  '4.88',
#  '6.14',
#  '6.26',
#  '8.87',
#  '11.54',
#  '18.33',
#  '15.54',
#  '17.07',
#  '23.76',
#  '32.71',
#  '51.29',
#  '60.44',
#  '71.34',
#  '$1.22',
#  '$4.76',
#  '$10.02',
#  '$15.99',
#  '$42.11']

# %%
avg3 = []
for c in avg2:
    new_avg3 = c.replace("$","") # taking out the dollar sign
    avg3.append(new_avg3)

# %%
avg3
# Out:
# ['1.13',
#  '1.24',
#  '2.46',
#  '2.16',
#  '2.94',
#  '4.88',
#  '6.14',
#  '6.26',
#  '8.87',
#  '11.54',
#  '18.33',
#  '15.54',
#  '17.07',
#  '23.76',
#  '32.71',
#  '51.29',
#  '60.44',
#  '71.34',
#  '1.22',
#  '4.76',
#  '10.02',
#  '15.99',
#  '42.11']

# %%
avg4 = [float(elem) for elem in avg3] # convert to float


print(avg4)
# Out:
# [1.13, 1.24, 2.46, 2.16, 2.94, 4.88, 6.14, 6.26, 8.87, 11.54, 18.33, 15.54, 17.07, 23.76, 32.71, 51.29, 60.44, 71.34, 1.22, 4.76, 10.02, 15.99, 42.11]

# %%
dollar_amount=avg4[18:23]

# %%
dollar_amount
# Out:
# [1.22, 4.76, 10.02, 15.99, 42.11]

# %%
cents_indollars=[]
for x in avg4[:18]:
    y = (x/100) # dividing by 100 to get the dollar amount
    cents_indollars.append(y)   
print(cents_indollars)
# Out:
# [0.0113, 0.0124, 0.0246, 0.0216, 0.0294, 0.048799999999999996, 0.061399999999999996, 0.0626, 0.08869999999999999, 0.11539999999999999, 0.1833, 0.15539999999999998, 0.1707, 0.2376, 0.3271, 0.5129, 0.6043999999999999, 0.7134]

# %%
avg_list=cents_indollars + dollar_amount

# %%
avg_list
# Out:
# [0.0113,
#  0.0124,
#  0.0246,
#  0.0216,
#  0.0294,
#  0.048799999999999996,
#  0.061399999999999996,
#  0.0626,
#  0.08869999999999999,
#  0.11539999999999999,
#  0.1833,
#  0.15539999999999998,
#  0.1707,
#  0.2376,
#  0.3271,
#  0.5129,
#  0.6043999999999999,
#  0.7134,
#  1.22,
#  4.76,
#  10.02,
#  15.99,
#  42.11]

# %% [markdown]
# ## Step 8: Coalesce the cleansed data and save them to a text file named "census_cost.csv"

# %%
top2_list
# Out:
# ['Source: https://www.genealogybranches.com/censuscosts.html\n',
#  'Census Year\tTotal Population\tCensus Cost\tAverage Cost Per Person\n']

# %%
new_top2_list= []
for d in top2_list:
    new_toplist = d.replace("\t",",") # taking out the "\t"
    new_top2_list.append(new_toplist)

# %%
new_top2_list
# Out:
# ['Source: https://www.genealogybranches.com/censuscosts.html\n',
#  'Census Year,Total Population,Census Cost,Average Cost Per Person\n']

# %%
with open("census_cost.csv", "tw") as f:
    for i in new_top2_list: # adding the 2 row first
        f.write(i)
    for i in range(len(year_list)): #appending and coverting into string 
        row=[]
        row.append(str(year_list[i]))
        row.append(str(pop_list[i]))
        row.append(str(cost_list[i]))
        row.append(str(avg_list[i]))
        f.write(",".join(row)+"\n") # adding \n so that they are in a different row

# %% [markdown]
# ## Step 9: Write code to open the newly-created file "census_cost.csv", read all lines and display them

# %%
with open("census_cost.csv", "rt") as f: # open file
    all_lines=f.readlines() # open file

# %%
type(all_lines)
# Out:
# list

# %%
print (all_lines)
# Out:
# ['Source: https://www.genealogybranches.com/censuscosts.html\n', 'Census Year,Total Population,Census Cost,Average Cost Per Person\n', '1790,3929214,44377,0.0113\n', '1800,5308483,66109,0.0124\n', '1810,7239881,178445,0.0246\n', '1820,9633822,208526,0.0216\n', '1830,12866020,378545,0.0294\n', '1840,17069458,833371,0.048799999999999996\n', '1850,23191876,1423351,0.061399999999999996\n', '1860,31443321,1969377,0.0626\n', '1870,38558371,3421198,0.08869999999999999\n', '1880,50155783,5790678,0.11539999999999999\n', '1890,62979766,11547127,0.1833\n', '1900,76303387,11854000,0.15539999999999998\n', '1910,91972266,15968000,0.1707\n', '1920,105710620,25117000,0.2376\n', '1930,122775046,40156000,0.3271\n', '1940,131669275,67527000,0.5129\n', '1950,151325798,91462000,0.6043999999999999\n', '1960,179323175,127934000,0.7134\n', '1970,203302031,247653000,1.22\n', '1980,226542199,1078488000,4.76\n', '1990,248718301,2492830000,10.02\n', '2000,281421906,4500000000,15.99\n', '2010,308745538,130000000
# ...

# %%
for row in all_lines: # printing the files
    print(row)
# Out:
# Source: https://www.genealogybranches.com/censuscosts.html
#
# Census Year,Total Population,Census Cost,Average Cost Per Person
#
# 1790,3929214,44377,0.0113
#
# 1800,5308483,66109,0.0124
#
# 1810,7239881,178445,0.0246
#
# 1820,9633822,208526,0.0216
#
# 1830,12866020,378545,0.0294
#
# 1840,17069458,833371,0.048799999999999996
#
# 1850,23191876,1423351,0.061399999999999996
#
# 1860,31443321,1969377,0.0626
#
# 1870,38558371,3421198,0.08869999999999999
#
# 1880,50155783,5790678,0.11539999999999999
#
# 1890,62979766,11547127,0.1833
#
# 1900,76303387,11854000,0.15539999999999998
#
# 1910,91972266,15968000,0.1707
#
# 1920,105710620,25117000,0.2376
#
# 1930,122775046,40156000,0.3271
#
# 1940,131669275,67527000,0.5129
#
# 1950,151325798,91462000,0.6043999999999999
#
# 1960,179323175,127934000,0.7134
#
# 1970,203302031,247653000,1.22
#
# 1980,226542199,1078488000,4.76
#
# 1990,248718301,2492830000,10.02
#
# 2000,281421906,4500000000,15.99
#
# 2010,308745538,13000000000,42.11

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5e850d88-26c1-4229-ad7b-bc0cc7c74f9d' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
