# %% [markdown]
# # Assignment 1
# ## Practice: Chapter 2
#
# **Name**: Shaimar R. González Morales
#
# **Date**: 1/31/2021

# %% [markdown]
# ### Step 1: The most simple code

# %%
print('hello, world')
# Out:
# hello, world

# %% [markdown]
# ### Step 2: Importing packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 3: Type

# %%
type('lola')
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(4.5)
# is use to comment the code and makes it easier to read
# Out:
# float

# %% [markdown]
# ### Step 4:Variables

# %%
flowers=['lillies, rose, magnolia']
flowers
# Out:
# ['lillies, rose, magnolia']

# %%
cost=[1,2,3]
c=cost
c.append(4)
cost
# since now cost is assigned to c if you make changes to c
#you are making changes to cost
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# **We can define a function to get to the same result**

# %%
def append_element(some_list, element):
    some_list.append(element)
append_element(cost,5)
cost
# as you can see some list is whatever list you have and element
# is whatever you are going to be adding to list
# Out:
# [1, 2, 3, 4, 5]

# %%
# let's try adding a str

append_element(cost,'lola')
cost
# Out:
# [1, 2, 3, 4, 5, 'lola']

# %% [markdown]
# ### Step 5: Dynamic references

# %%
# you can't add a str to an int

'lola' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-7b0c24ed54f2> in <module>
#       1 # you can't add a str to an int
#       2
# ----> 3 'lola' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
# any division that doesn't give a complete number will result in a float

x=5/2
type(x)
# Out:
# float

# %%
# we can use type to know the type of an object but
#isinstance can be used to ask specific questions is is a bool, int, float, ect.

isinstance(5,bool)
# Out:
# False

# %%
# isinstance can be also to see if the objects are from that type in tuple

b=7.9 ; d="lola"
isinstance(b,(float, str))
# Out:
# True

# %% [markdown]
# ### Step 6: Binary operators and comparisons

# %% [markdown]
# *Python as calculator*

# %%
1-2 # substraction
# Out:
# -1

# %%
5/ 30 # division
# Out:
# 0.16666666666666666

# %%
6+6 # sum
# Out:
# 12

# %%
6*7 # multiplication
# Out:
# 42

# %%
5**5 # ** elevated to x
# Out:
# 3125

# %%
5//2 # give back an int because drop fractional remainder
# Out:
# 2

# %% [markdown]
# *Comparisons*

# %%
cost==flowers # equal
# Out:
# False

# %%
cost != flowers # not equal
# Out:
# True

# %%
4 < 5 # less than
# Out:
# True

# %%
5 > 7 # more than
# Out:
# False

# %%
5 >=5 # more than or equal to
#<= less or equal
# Out:
# True

# %% [markdown]
# ### Step 7: Mutables and immutable objects

# %%
# you can't alter the content of a touple
lore1=('wo', 7, 3, (5, 7))
lore1[2]= 5,(4,8)
lore1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0e9d2628a1bd> in <module>
#       1 # you can't alter the content of a touple
#       2 lore1=('wo', 7, 3, (5, 7))
# ----> 3 lore1[2]= 5,(4,8)
#       4 lore1
#
# TypeError: 'tuple' object does not support item assignment

# %%
# you can alter the content of a list
lore2=['wo', 7, 3, [5, 7]]
lore2[2]= 5,(4,8)
lore2
# Out:
# ['wo', 7, (5, (4, 8)), [5, 7]]

# %% [markdown]
# ### Step 8: Strings

# %%
# a string can't be modified

c= "bear"
c[4]=3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-fb8dc51dc3db> in <module>
#       2
#       3 c= "bear"
# ----> 4 c[4]=3
#
# TypeError: 'str' object does not support item assignment

# %%
# int can be modified to a string

c= 4
str(4)
# Out:
# '4'

# %%
# float as well can be modified to a string
nol=4.6
str(nol)
# Out:
# '4.6'

# %%
# a string can be converted into a list
f="ballon"
list(f)
# Out:
# ['b', 'a', 'l', 'l', 'o', 'n']

# %%
# that list can be slice
f[:4] # the slice don't count the endpoint
# Out:
# 'ball'

# %%
# string formating
s='{0:s} movie is number {1:d} in charts'
s
s.format('The Devils Wear Prada', 34 )
# Out:
# 'The Devils Wear Prada movie is number 34 in charts'

# %% [markdown]
# ### Step 9: is and is not

# %%
# None is null value
m= None
f is None
# act in this case similar to ==
# Out:
# False

# %%
f is not m
# act similar to !=
# Out:
# True

# %%
#the None value is also used sometimes when defining a function 
#It is used to indicate if the value is not null then perform certain action

# %% [markdown]
# ### Step 10: Days and times

# %%
from datetime import datetime,date,time

today = datetime(2021, 2,1, 8, 30, 21)

# %%
a=today.year #first part indicate year
b=today.date # second the day
c=today.hour # third the hour
d=today.minute # fourth the minutes
e=today.second #fith indicates seconds
a
# Out:
# 2021

# %%
e
# Out:
# 21

# %%
today.date()# if you are interested in just the day
# Out:
# datetime.date(2021, 2, 1)

# %%
today.time()# if you are interested in just the time
# Out:
# datetime.time(8, 30, 21)

# %%
today.strftime('%m/%d/%Y %H:%M:%S') 
# strftime convert the information to a string
# Out:
# '02/01/2021 08:30:21'

# %%
today.strptime('02/01/2021 08:30:21','%m/%d/%Y %H:%M:%S')
#you can use strptime to revert the code to datetime format
# Out:
# datetime.datetime(2021, 2, 1, 8, 30, 21)

# %%
tomorrow=datetime(2021, 2, 2, 10, 45, 40)

# %%
seg=tomorrow-today
#you can look at the differences between days

# %%
type(seg)
# the substractions of the datetime generate a timedelta object
# Out:
# datetime.timedelta

# %% [markdown]
# ### Step 11: Control flow

# %% [markdown]
# *if*

# %%
roses="red"

# %%
if roses =="red":
    print("beutiful") # helps check if a condition is True
# Out:
# beutiful

# %%
b=7

# %%
if b == 3:
    print('hey 3')
    
elif b == 8:
    print('hey 8')
elif b< 5:
    print('lower than 5')
else:
    print("b is still not found")

#if used with elif and else help to explore if the condition is false
# Out:
# b is still not found

# %% [markdown]
# *for loops*

# %%
bingo=[3, 6, 5, 8, 10]
total=0

# %%
for value in bingo:
    if value ==5:
        continue
    total += value

# %%
total #it added all the number in the list because one of them was 5
# Out:
# 27

# %%
total_5=0

# %%
for value in bingo:
    if value ==5:
        break
    total_5 += value

# %%
total_5 # in this case not like the code above is actually going to the lis
#until there is 5 and is not adding anything else to the total
#as in before it added everything in the list except 5
# Out:
# 9

# %% [markdown]
# *While loops*

# %%
#while loops are use to verify the condition until is false
h = 698
total = 0
while h > 0:
    if total < 700: #h is less than 700
        break
        total += h
        h=h//100

# %%
x = 5
total = 0
if x == 0:
    print('it is zero')
elif x < 0:
    print('it is negative')
elif x >6:
        pass
else:
    print('1-5')

#pass no action happening
# Out:
# 1-5

# %% [markdown]
# *range*

# %%
range(7) # it return an int
# Out:
# range(0, 7)

# %%
list(range(7)) #it return a list of the range 
# it include zero as python start counting from zero, a total of 7 numbers
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list(range(0, 18, 3))# this indicates that I want a range from 0 to 18
# and that I want that range in divisibles of 3
# Out:
# [0, 3, 6, 9, 12, 15]

# %%
# range also is used in loops and/or if statements to determine wether the variable
#is in the length of the range ex.

nur = [0,1, 2, 3, 4, 5]
if 5 in range(len(nur)):
    print('I am here')
# Out:
# I am here
